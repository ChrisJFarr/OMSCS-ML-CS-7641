# %%
import os

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from pprint import pprint


# Start from assignment1 directory
current_dir = os.getcwd().split("/")[-1]
if current_dir != "assignment1":
    os.chdir("..")
current_dir = os.getcwd().split("/")[-1]
assert current_dir=="assignment1", "failed to reach target directory"

# %%
"""
Explore diabetes-health-indicators dataset

* Load data
* Count examples
* Evaluate missingness
* Evaluate feature distributions
* Test for skewness and make notes
* Identify target
* Evaluate class balance
* Describe SL problem to solve
* Describe importance and relevance of problem
* Are there additional insights that can be gained from solving similar problem across two datasets?

"""

# Load data
data_path = "data/diabetes_012_health_indicators_BRFSS2015.csv"
df = pd.read_csv(data_path)

# Count examples
print("Number of examples: %s" % df.shape[0])
print("Number of features: %s" % (df.shape[1]-1))
print("Number of positive examples: %s" % (df["Diabetes_012"]>0).sum())
print("Number of negative examples: %s" % (df.shape[0]-(df["Diabetes_012"]>0).sum()))
# Out:
# Number of examples: 253680
# Number of features: 21
# Number of positive examples: 39977
# Number of negative examples: 213703

# %%
print("Percent positive examples: %.2f%%" % ((df["Diabetes_012"]>0).mean()*100))
# Out:
# Percent positive examples: 15.76%

# %%
pprint(list(df.columns))
# Out:
# ['Diabetes_012',
#  'HighBP',
#  'HighChol',
#  'CholCheck',
#  'BMI',
#  'Smoker',
#  'Stroke',
#  'HeartDiseaseorAttack',
#  'PhysActivity',
#  'Fruits',
#  'Veggies',
#  'HvyAlcoholConsump',
#  'AnyHealthcare',
#  'NoDocbcCost',
#  'GenHlth',
#  'MentHlth',
#  'PhysHlth',
#  'DiffWalk',
#  'Sex',
#  'Age',
#  'Education',
#  'Income']

# %% [markdown]
# **Notes**
# * CholCheck, Stroke, HvyAlcoholConsump, AnyHealthCare: severely imbalanced binary
# * HeartDiseaseOrAttack, NoDoccCost: very imbalanced binary
# * Diabetes target is imbalanced

# %%
for col in df.columns:
    df[col].hist(bins=10)
    plt.title("%s Distribution" % col)
    plt.show()
